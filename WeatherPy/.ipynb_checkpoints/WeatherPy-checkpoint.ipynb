# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
# import matplotlib.pyplot as plt
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import requests
from scipy.stats import linregress
from scipy import stats
import os
import csv

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="

# Set lists
city_list = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
count=0

# Loop through the list of cities and perform a request for data on each
print("Beginning Data Retrieval")
print("-----------------------------")
for city in cities:
    response = requests.get(query_url + city).json()
    try:
        print(f"Processing Record {count}"+f" ID:{response['id']}"f" | {response['name']}.")
        city_list.append(response['name'])
        cloudiness.append(response['clouds']['all'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lat.append(response['coord']['lat'])
        lng.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        wind_speed.append(response['wind']['speed'])
        count+=1
    except:
        print("City not found. Skipping...")
        
print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 0 ID:3874787 | Punta Arenas.
# Processing Record 1 ID:1490256 | Talnakh.
# Processing Record 2 ID:6148373 | Sioux Lookout.
# Processing Record 3 ID:2446796 | Bilma.
# Processing Record 4 ID:6145425 | Shaunavon.
# Processing Record 5 ID:603570 | Pitea.
# Processing Record 6 ID:2068655 | Katherine.
# Processing Record 7 ID:2155415 | New Norfolk.
# Processing Record 8 ID:1651810 | Airai.
# Processing Record 9 ID:1735106 | George Town.
# Processing Record 10 ID:233019 | Kaberamaido.
# Processing Record 11 ID:3443061 | Chui.
# Processing Record 12 ID:187585 | Marsabit.
# City not found. Skipping...
# Processing Record 13 ID:2012530 | Zhigansk.
# Processing Record 14 ID:3461888 | Guarapari.
# Processing Record 15 ID:2065594 | Mount Isa.
# Processing Record 16 ID:2110227 | Butaritari.
# Processing Record 17 ID:6201424 | Mataura.
# City not found. Skipping...
# Processing Record 18 ID:2126123 | Chokurdakh.
# Processing Record 19 ID:2377457 | Nouadhibou.
# Processing Record 20 ID:2017155 | Saskylakh.
# Processing Record 21 ID:1507390 | Dikson.
# Processing Record 22 ID:2208248 | Kaitangata.
# Processing Record 23 ID:4030556 | Rikitea.
# Processing Record 24 ID:2163355 | Hobart.
# Processing Record 25 ID:3372707 | Ribeira Grande.
# Processing Record 26 ID:964432 | Port Alfred.
# Processing Record 27 ID:3421765 | Nanortalik.
# Processing Record 28 ID:2075265 | Busselton.
# Processing Record 29 ID:3366880 | Hermanus.
# Processing Record 30 ID:546105 | Nikolskoye.
# Processing Record 31 ID:4020109 | Atuona.
# Processing Record 32 ID:3385883 | Uaua.
# Processing Record 33 ID:884927 | Mutoko.
# Processing Record 34 ID:2729907 | Longyearbyen.
# Processing Record 35 ID:1265645 | Kumta.
# Processing Record 36 ID:2206939 | Bluff.
# Processing Record 37 ID:3418910 | Upernavik.
# Processing Record 38 ID:1015776 | Bredasdorp.
# Processing Record 39 ID:4021858 | Guerrero Negro.
# Processing Record 40 ID:934322 | Mahebourg.
# Processing Record 41 ID:5546220 | Saint George.
# Processing Record 42 ID:6165406 | Thompson.
# Processing Record 43 ID:6173864 | Vernon.
# Processing Record 44 ID:3833367 | Ushuaia.
# Processing Record 45 ID:3361934 | Saldanha.
# Processing Record 46 ID:935214 | Saint-Pierre.
# City not found. Skipping...
# Processing Record 47 ID:3984997 | San Quintin.
# Processing Record 48 ID:3471451 | Arraial do Cabo.
# Processing Record 49 ID:3985710 | Cabo San Lucas.
# Processing Record 50 ID:2963218 | Kilrush.
# Processing Record 51 ID:5106841 | Albany.
# Processing Record 52 ID:2434979 | Bol.
# City not found. Skipping...
# Processing Record 53 ID:3424607 | Tasiilaq.
# Processing Record 54 ID:5364022 | La Palma.
# Processing Record 55 ID:964420 | Port Elizabeth.
# Processing Record 56 ID:2022572 | Khatanga.
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 57 ID:2264557 | Ponta do Sol.
# Processing Record 58 ID:174982 | Armenia.
# Processing Record 59 ID:5110365 | Broome.
# Processing Record 60 ID:1714733 | Dingle.
# Processing Record 61 ID:2146219 | Hervey Bay.
# Processing Record 62 ID:3571913 | Marsh Harbour.
# Processing Record 63 ID:3369157 | Cape Town.
# Processing Record 64 ID:1267776 | Kargil.
# Processing Record 65 ID:5880054 | Barrow.
# Processing Record 66 ID:158563 | Kakonko.
# Processing Record 67 ID:3466704 | Castro.
# Processing Record 68 ID:2258261 | Dolisie.
# Processing Record 69 ID:1797132 | Rizhao.
# Processing Record 70 ID:5870133 | Nome.
# Processing Record 71 ID:4031574 | Provideniya.
# Processing Record 72 ID:5072006 | Lincoln.
# City not found. Skipping...
# Processing Record 73 ID:110690 | Faya.
# Processing Record 74 ID:6170031 | Tuktoyaktuk.
# Processing Record 75 ID:1529569 | Changji.
# Processing Record 76 ID:5848280 | Kapaa.
# Processing Record 77 ID:2074865 | Carnarvon.
# Processing Record 78 ID:6078372 | Moose Factory.
# Processing Record 79 ID:3728097 | Les Cayes.
# Processing Record 80 ID:3652764 | Puerto Ayora.
# Processing Record 81 ID:3578278 | Vieux-Habitants.
# Processing Record 82 ID:53372 | Oodweyne.
# City not found. Skipping...
# Processing Record 83 ID:932183 | Quthing.
# Processing Record 84 ID:4032243 | Vaini.
# Processing Record 85 ID:2426370 | Oum Hadjer.
# Processing Record 86 ID:145531 | Saurimo.
# Processing Record 87 ID:1795632 | Shenjiamen.
# Processing Record 88 ID:3893726 | Constitucion.
# Processing Record 89 ID:1214488 | Meulaboh.
# City not found. Skipping...
# Processing Record 90 ID:5924351 | Clyde River.
# Processing Record 91 ID:3380290 | Sinnamary.
# Processing Record 92 ID:3393536 | Olinda.
# Processing Record 93 ID:3932145 | Pisco.
# Processing Record 94 ID:1052373 | Beira.
# Processing Record 95 ID:5855927 | Hilo.
# City not found. Skipping...
# Processing Record 96 ID:3576994 | Cockburn Town.
# Processing Record 97 ID:3869716 | Tocopilla.
# Processing Record 98 ID:2168305 | Dubbo.
# Processing Record 99 ID:1524296 | Esil.
# Processing Record 100 ID:1819729 | Hong Kong.
# Processing Record 101 ID:5367788 | Lompoc.
# Processing Record 102 ID:4518264 | Middletown.
# Processing Record 103 ID:7671223 | Kloulklubed.
# Processing Record 104 ID:5122534 | Jamestown.
# Processing Record 105 ID:2122605 | Okhotsk.
# Processing Record 106 ID:6111696 | Port-Cartier.
# Processing Record 107 ID:1629974 | Rantepao.
# Processing Record 108 ID:8010683 | Porto Santo.
# City not found. Skipping...
# Processing Record 109 ID:1738050 | Marabu.
# Processing Record 110 ID:4010155 | Coyote.
# Processing Record 111 ID:5972762 | Hay River.
# Processing Record 112 ID:1045114 | Inhambane.
# Processing Record 113 ID:2123814 | Leningradskiy.
# Processing Record 114 ID:4013679 | Coahuayana Viejo.
# Processing Record 115 ID:1486321 | Yar-Sale.
# Processing Record 116 ID:780687 | Berlevag.
# Processing Record 117 ID:1633419 | Padang.
# Processing Record 118 ID:3461408 | Ilheus.
# Processing Record 119 ID:1513491 | Yangi Marg`ilon.
# Processing Record 120 ID:3421719 | Narsaq.
# Processing Record 121 ID:2012956 | Yerbogachen.
# Processing Record 122 ID:1516048 | Khovd.
# Processing Record 123 ID:2079582 | Alyangula.
# Processing Record 124 ID:6089245 | Norman Wells.
# Processing Record 125 ID:3894426 | Coyhaique.
# Processing Record 126 ID:2171766 | Charlestown.
# Processing Record 127 ID:778707 | Mehamn.
# Processing Record 128 ID:304183 | Bayir.
# Processing Record 129 ID:523392 | Nar'yan-Mar.
# Processing Record 130 ID:933995 | Souillac.
# Processing Record 131 ID:3175096 | Laas.
# Processing Record 132 ID:5808079 | Redmond.
# Processing Record 133 ID:296852 | Erzin.
# Processing Record 134 ID:4362001 | Mayo.
# Processing Record 135 ID:4249910 | Shiloh.
# Processing Record 136 ID:1174167 | Khanpur.
# Processing Record 137 ID:5882953 | Aklavik.
# Processing Record 138 ID:4036284 | Alofi.
# Processing Record 139 ID:3372472 | Vila Franca do Campo.
# Processing Record 140 ID:2239862 | Malanje.
# Processing Record 141 ID:2122090 | Pevek.
# City not found. Skipping...
# Processing Record 142 ID:103630 | Najran.
# Processing Record 143 ID:3408404 | Abreu e Lima.
# Processing Record 144 ID:3423146 | Ilulissat.
# Processing Record 145 ID:2092164 | Lorengau.
# Processing Record 146 ID:5606401 | Sandpoint.
# Processing Record 147 ID:5861897 | Fairbanks.
# Processing Record 148 ID:3449195 | Sao Fidelis.
# Processing Record 149 ID:1498087 | Nadym.
# Processing Record 150 ID:6324729 | Halifax.
# Processing Record 151 ID:3430863 | Mar del Plata.
# Processing Record 152 ID:3691582 | Talara.
# Processing Record 153 ID:2121025 | Srednekolymsk.
# Processing Record 154 ID:2132606 | Samarai.
# Processing Record 155 ID:2015306 | Tiksi.
# Processing Record 156 ID:5380420 | Pacifica.
# Processing Record 157 ID:3388456 | Sao Jose da Coroa Grande.
# City not found. Skipping...
# Processing Record 158 ID:1215502 | Banda Aceh.
# Processing Record 159 ID:1899102 | Nagato.
# Processing Record 160 ID:1850523 | Tateyama.
# Processing Record 161 ID:5866583 | Kodiak.
# Processing Record 162 ID:1282256 | Hithadhoo.
# City not found. Skipping...
# Processing Record 163 ID:777019 | Vardo.
# Processing Record 164 ID:215605 | Kabare.
# Processing Record 165 ID:2023190 | Kangalassy.
# Processing Record 166 ID:686090 | Asau.
# Processing Record 167 ID:4035715 | Avarua.
# Processing Record 168 ID:1048364 | Chokwe.
# Processing Record 169 ID:2026786 | Berezovyy.
# Processing Record 170 ID:6167817 | Torbay.
# Processing Record 171 ID:3883457 | Lebu.
# Processing Record 172 ID:3386177 | Trairi.
# Processing Record 173 ID:2016307 | Solnechnyy.
# Processing Record 174 ID:935215 | Saint-Philippe.
# Processing Record 175 ID:1502725 | Yugorsk.
# Processing Record 176 ID:1266038 | Kotagiri.
# Processing Record 177 ID:1526038 | Atbasar.
# Processing Record 178 ID:2013923 | Ust'-Kut.
# Processing Record 179 ID:2070998 | Geraldton.
# Processing Record 180 ID:2396518 | Port-Gentil.
# Processing Record 181 ID:6113406 | Prince Rupert.
# Processing Record 182 ID:1629001 | Samarinda.
# Processing Record 183 ID:477039 | Varenikovskaya.
# Processing Record 184 ID:1106677 | Bambous Virieux.
# Processing Record 185 ID:3374083 | Bathsheba.
# Processing Record 186 ID:4513583 | Hamilton.
# Processing Record 187 ID:2180991 | Tolaga Bay.
# Processing Record 188 ID:7117100 | Vila.
# Processing Record 189 ID:525426 | Sobolevo.
# Processing Record 190 ID:2618795 | Klaksvik.
# Processing Record 191 ID:2745087 | Gemeente Wageningen.
# Processing Record 192 ID:509437 | Pionerskiy.
# Processing Record 193 ID:2082539 | Merauke.
# Processing Record 194 ID:962367 | Richards Bay.
# Processing Record 195 ID:934479 | Grand Gaube.
# Processing Record 196 ID:3386213 | Touros.
# Processing Record 197 ID:3892454 | Diego de Almagro.
# Processing Record 198 ID:2126710 | Beringovskiy.
# Processing Record 199 ID:1283285 | Jumla.
# Processing Record 200 ID:3407762 | Amapa.
# Processing Record 201 ID:3674010 | Natagaima.
# Processing Record 202 ID:1835848 | Seoul.
# Processing Record 203 ID:1814093 | Dali.
# Processing Record 204 ID:1337607 | Kudahuvadhoo.
# Processing Record 205 ID:2227402 | Meiganga.
# Processing Record 206 ID:2032201 | Bulgan.
# Processing Record 207 ID:2071860 | Esperance.
# Processing Record 208 ID:3761194 | Miraflores.
# Processing Record 209 ID:143073 | Ardakan.
# City not found. Skipping...
# Processing Record 210 ID:3408064 | Remanso.
# Processing Record 211 ID:2121385 | Severo-Kuril'sk.
# Processing Record 212 ID:86049 | Jalu.
# Processing Record 213 ID:4563243 | Carolina.
# Processing Record 214 ID:1812256 | Dongsheng.
# Processing Record 215 ID:4034188 | Moerai.
# Processing Record 216 ID:1800657 | Mentougou.
# Processing Record 217 ID:1651531 | Ambon.
# Processing Record 218 ID:3355672 | Luderitz.
# Processing Record 219 ID:1633442 | Paciran.
# Processing Record 220 ID:3448903 | Sao Joao da Barra.
# Processing Record 221 ID:2112802 | Hasaki.
# Processing Record 222 ID:1607758 | Phayao.
# Processing Record 223 ID:1862505 | Hirara.
# Processing Record 224 ID:2155562 | Nelson Bay.
# Processing Record 225 ID:2014573 | Uglekamensk.
# Processing Record 226 ID:3982168 | Tecuala.
# Processing Record 227 ID:1734199 | Tawao.
# Processing Record 228 ID:2619537 | Hvide Sande.
# Processing Record 229 ID:6620339 | Karratha.
# Processing Record 230 ID:2194098 | Ahipara.
# Processing Record 231 ID:478050 | Ust'-Kulom.
# Processing Record 232 ID:3372760 | Praia da Vitoria.
# Processing Record 233 ID:2018069 | Peleduy.
# Processing Record 234 ID:2164457 | Grenfell.
# Processing Record 235 ID:1688781 | City of San Pedro.
# Processing Record 236 ID:1067565 | Beloha.
# Processing Record 237 ID:3137469 | Sorland.
# Processing Record 238 ID:3414079 | Olafsvik.
# Processing Record 239 ID:2129376 | Kushiro.
# Processing Record 240 ID:712715 | Bazaliia.
# Processing Record 241 ID:2180815 | Tuatapere.
# Processing Record 242 ID:2142316 | Yeppoon.
# Processing Record 243 ID:2126199 | Cherskiy.
# Processing Record 244 ID:2367164 | Dapaong.
# Processing Record 245 ID:580676 | Asekeyevo.
# Processing Record 246 ID:3466165 | Cidreira.
# Processing Record 247 ID:2015217 | Tokur.
# Processing Record 248 ID:2176639 | Batemans Bay.
# Processing Record 249 ID:1568574 | Qui Nhon.
# Processing Record 250 ID:3387423 | Sitio Novo do Tocantins.
# Processing Record 251 ID:3440777 | Rocha.
# Processing Record 252 ID:1006984 | East London.
# Processing Record 253 ID:1607016 | Rayong.
# Processing Record 254 ID:684870 | Bilbor.
# Processing Record 255 ID:3372964 | Lagoa.
# Processing Record 256 ID:3453315 | Pocone.
# Processing Record 257 ID:5911745 | Burns Lake.
# Processing Record 258 ID:6071876 | Melfort.
# Processing Record 259 ID:5746545 | Portland.
# Processing Record 260 ID:1249931 | Beruwala.
# Processing Record 261 ID:1276815 | Barwala.
# Processing Record 262 ID:2122104 | Petropavlovsk-Kamchatsky.
# Processing Record 263 ID:762199 | Pionki.
# City not found. Skipping...
# Processing Record 264 ID:4231997 | Avera.
# Processing Record 265 ID:2294915 | Takoradze.
# Processing Record 266 ID:4034551 | Faanui.
# Processing Record 267 ID:486413 | Suksun.
# Processing Record 268 ID:6943832 | Riviere-au-Renard.
# City not found. Skipping...
# Processing Record 269 ID:5012495 | Traverse City.
# Processing Record 270 ID:1855540 | Naze.
# Processing Record 271 ID:608872 | Makat.
# Processing Record 272 ID:5557293 | Sitka.
# Processing Record 273 ID:3648522 | Barquisimeto.
# Processing Record 274 ID:4074277 | Madison.
# Processing Record 275 ID:570479 | Khalimbekaul.
# Processing Record 276 ID:1630723 | Poso.
# Processing Record 277 ID:3412093 | Vestmannaeyjar.
# Processing Record 278 ID:986717 | Kruisfontein.
# Processing Record 279 ID:1847947 | Shingu.
# Processing Record 280 ID:1809461 | Guiyang.
# Processing Record 281 ID:2094342 | Kavieng.
# Processing Record 282 ID:5307540 | Oro Valley.
# Processing Record 283 ID:5905393 | Bonavista.
# Processing Record 284 ID:463655 | Zenzeli.
# Processing Record 285 ID:10722858 | Forsytheganj.
# Processing Record 286 ID:1250161 | Batticaloa.
# Processing Record 287 ID:4323900 | Eunice.
# Processing Record 288 ID:4713738 | Nacogdoches.
# Processing Record 289 ID:5380437 | Pacific Grove.
# Processing Record 290 ID:7647007 | Bariloche.
# City not found. Skipping...
# Processing Record 291 ID:5392171 | San Jose.
# Processing Record 292 ID:1242110 | Kalmunai.
# Processing Record 293 ID:1279110 | Akodia.
# Processing Record 294 ID:2028164 | Deputatsky.
# Processing Record 295 ID:286621 | Salalah.
# Processing Record 296 ID:74185 | Jiblah.
# Processing Record 297 ID:1272502 | Diu.
# Processing Record 298 ID:3451138 | Rio Grande.
# Processing Record 299 ID:3936456 | Lima.
# Processing Record 300 ID:64013 | Bosaso.
# Processing Record 301 ID:2206874 | Waipawa.
# Processing Record 302 ID:2963155 | Kinsale.
# Processing Record 303 ID:6050066 | La Ronge.
# Processing Record 304 ID:1349090 | Harindanga.
# Processing Record 305 ID:2210560 | Surman.
# Processing Record 306 ID:8079926 | Labuhan.
# Processing Record 307 ID:57000 | Hobyo.
# City not found. Skipping...
# Processing Record 308 ID:3884373 | La Serena.
# Processing Record 309 ID:2315026 | Kasongo-Lunda.
# Processing Record 310 ID:5703673 | Elko.
# Processing Record 311 ID:1255482 | Sullia.
# Processing Record 312 ID:64814 | Bandarbeyla.
# City not found. Skipping...
# Processing Record 313 ID:161974 | Bereket.
# City not found. Skipping...
# Processing Record 314 ID:3441890 | Departamento de Maldonado.
# Processing Record 315 ID:2140466 | Moindou.
# Processing Record 316 ID:1494482 | Polunochnoye.
# Processing Record 317 ID:1789647 | Xichang.
# Processing Record 318 ID:70979 | Sayyan.
# City not found. Skipping...
# Processing Record 319 ID:1806840 | Huilong.
# Processing Record 320 ID:3450083 | Santa Maria.
# Processing Record 321 ID:1649150 | Bengkulu.
# Processing Record 322 ID:2276492 | Harper.
# Processing Record 323 ID:3449747 | Santa Vitoria do Palmar.
# Processing Record 324 ID:2487130 | Sidi Ali.
# Processing Record 325 ID:3887127 | Iquique.
# City not found. Skipping...
# Processing Record 326 ID:777682 | Skjervoy.
# Processing Record 327 ID:3533462 | Acapulco de Juarez.
# Processing Record 328 ID:1849831 | Toyooka.
# Processing Record 329 ID:6185377 | Yellowknife.
# Processing Record 330 ID:2062381 | Robe.
# Processing Record 331 ID:5364916 | Lamont.
# City not found. Skipping...
# Processing Record 332 ID:2455290 | Kidal.
# Processing Record 333 ID:2980080 | Saint-Francois.
# Processing Record 334 ID:3353871 | Otjimbingwe.
# Processing Record 335 ID:2644210 | Liverpool.
# Processing Record 336 ID:2137773 | Vao.
# Processing Record 337 ID:494884 | Shenkursk.
# Processing Record 338 ID:1608524 | Nakhon Thai.
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 339 ID:509017 | Pleshanovo.
# Processing Record 340 ID:1037125 | Montepuez.
# Processing Record 341 ID:608324 | Shetpe.
# Processing Record 342 ID:1798425 | Puyang.
# Processing Record 343 ID:3533826 | Yaguajay.
# Processing Record 344 ID:5282297 | Bethel.
# Processing Record 345 ID:1278282 | Asifabad.
# Processing Record 346 ID:1526273 | Astana.
# Processing Record 347 ID:1337618 | Manadhoo.
# Processing Record 348 ID:1244926 | Hambantota.
# Processing Record 349 ID:5952370 | Fernie.
# Processing Record 350 ID:3416888 | Grindavik.
# Processing Record 351 ID:115019 | Shiraz.
# Processing Record 352 ID:316634 | Dinar.
# Processing Record 353 ID:3906466 | Riberalta.
# Processing Record 354 ID:609924 | Emba.
# Processing Record 355 ID:2063042 | Port Hedland.
# Processing Record 356 ID:5044290 | Saint Anthony.
# Processing Record 357 ID:3421319 | Nuuk.
# Processing Record 358 ID:3385899 | Tutoia.
# Processing Record 359 ID:3460531 | Ituacu.
# Processing Record 360 ID:2409914 | Bonthe.
# Processing Record 361 ID:934649 | Cap Malheureux.
# Processing Record 362 ID:5710360 | Winnemucca.
# Processing Record 363 ID:1636426 | Manggar.
# Processing Record 364 ID:4636045 | Lebanon.
# Processing Record 365 ID:3947956 | Ambo.
# Processing Record 366 ID:645036 | Nastola.
# Processing Record 367 ID:149812 | Sokoni.
# Processing Record 368 ID:3141667 | Roald.
# Processing Record 369 ID:2138555 | Poum.
# Processing Record 370 ID:5972291 | Havre-Saint-Pierre.
# City not found. Skipping...
# Processing Record 371 ID:656820 | Iisalmi.
# Processing Record 372 ID:2039557 | Khasan.
# Processing Record 373 ID:2063036 | Port Lincoln.
# Processing Record 374 ID:3664980 | Boa Vista.
# Processing Record 375 ID:566868 | Dedovichi.
# Processing Record 376 ID:2401495 | Booue.
# Processing Record 377 ID:1795184 | Shilong.
# Processing Record 378 ID:3446038 | Trindade.
# Processing Record 379 ID:1489499 | Togur.
# Processing Record 380 ID:2138522 | Poya.
# Processing Record 381 ID:1529376 | Korla.
# City not found. Skipping...
# Processing Record 382 ID:2013279 | Vostok.
# Processing Record 383 ID:4845585 | Westport.
# Processing Record 384 ID:1490085 | Tarko-Sale.
# Processing Record 385 ID:568822 | Chernitsyno.
# Processing Record 386 ID:2186111 | Ngunguru.
# Processing Record 387 ID:1493162 | Salym.
# Processing Record 388 ID:4513409 | Grove City.
# Processing Record 389 ID:3470137 | Belmonte.
# Processing Record 390 ID:1651591 | Amahai.
# Processing Record 391 ID:1621313 | Ambulu.
# Processing Record 392 ID:4944903 | Nantucket.
# Processing Record 393 ID:3470837 | Barbosa Ferraz.
# Processing Record 394 ID:110690 | Abha.
# Processing Record 395 ID:2630299 | Hofn.
# Processing Record 396 ID:3361142 | Springbok.
# Processing Record 397 ID:1791779 | Wanning.
# Processing Record 398 ID:823676 | Gornoye Loo.
# Processing Record 399 ID:3899695 | Ancud.
# Processing Record 400 ID:1586443 | Ca Mau.
# Processing Record 401 ID:3599575 | Barillas.
# Processing Record 402 ID:2027806 | Amazar.
# Processing Record 403 ID:905395 | Mufulira.
# Processing Record 404 ID:2108502 | Honiara.
# Processing Record 405 ID:2098329 | Daru.
# Processing Record 406 ID:3191648 | Zlobin.
# Processing Record 407 ID:3831208 | Qaanaaq.
# Processing Record 408 ID:1214882 | Kisaran.
# Processing Record 409 ID:645212 | Naantali.
# Processing Record 410 ID:3115824 | Muros.
# Processing Record 411 ID:1651103 | Atambua.
# Processing Record 412 ID:2561668 | Agadir.
# Processing Record 413 ID:1283334 | Birin.
# Processing Record 414 ID:4505215 | Amberley.
# City not found. Skipping...
# Processing Record 415 ID:3625929 | Tucupita.
# Processing Record 416 ID:1582886 | Kwang Binh.
# Processing Record 417 ID:3870243 | Taltal.
# Processing Record 418 ID:1258338 | Ratnagiri.
# Processing Record 419 ID:3466980 | Caravelas.
# Processing Record 420 ID:1622318 | Waingapu.
# Processing Record 421 ID:6145890 | Shelburne.
# Processing Record 422 ID:140097 | Borazjan.
# Processing Record 423 ID:2501152 | Constantine.
# Processing Record 424 ID:2639144 | Rosehearty.
# Processing Record 425 ID:2522325 | Aguimes.
# Processing Record 426 ID:4172445 | Seminole.
# Processing Record 427 ID:3383494 | Moengo.
# Processing Record 428 ID:1498161 | Muzhi.
# Processing Record 429 ID:1489057 | Tugulym.
# Processing Record 430 ID:3458329 | Luziania.
# Processing Record 431 ID:2022773 | Khandyga.
# Processing Record 432 ID:3421982 | Maniitsoq.
# Processing Record 433 ID:4012593 | Creel.
# Processing Record 434 ID:695298 | Rozvadiv.
# Processing Record 435 ID:2214432 | Nalut.
# Processing Record 436 ID:2037335 | Fuyu.
# Processing Record 437 ID:286245 | Sur.
# Processing Record 438 ID:863061 | Usinsk.
# Processing Record 439 ID:1605277 | Trat.
# Processing Record 440 ID:55671 | Kismayo.
# Processing Record 441 ID:1501377 | Kungurtug.
# Processing Record 442 ID:2958128 | Alsfeld.
# Processing Record 443 ID:127403 | Khomeyn.
# Processing Record 444 ID:172515 | Abu Samrah.
# Processing Record 445 ID:5118743 | Gloversville.
# Processing Record 446 ID:4035249 | Lufilufi.
# Processing Record 447 ID:1794209 | Simao.
# Processing Record 448 ID:3179347 | Cattolica.
# Processing Record 449 ID:287832 | Ibra.
# Processing Record 450 ID:2336237 | Jega.
# Processing Record 451 ID:470546 | Vyborg.
# Processing Record 452 ID:2381334 | Atar.
# Processing Record 453 ID:3382160 | Cayenne.
# Processing Record 454 ID:496358 | Severnyy.
# Processing Record 455 ID:6180285 | Whitecourt.
# Processing Record 456 ID:2136825 | Isangel.
# Processing Record 457 ID:3377301 | Mabaruma.
# City not found. Skipping...
# Processing Record 458 ID:3981391 | Tomatlan.
# Processing Record 459 ID:4566022 | Loiza.
# City not found. Skipping...
# Processing Record 460 ID:57289 | Hargeisa.
# Processing Record 461 ID:161943 | Gumdag.
# Processing Record 462 ID:1488167 | Ust'-Koksa.
# Processing Record 463 ID:2633274 | Akureyri.
# Processing Record 464 ID:1729564 | Bacolod City.
# City not found. Skipping...
# Processing Record 465 ID:2643044 | Margate.
# Processing Record 466 ID:58933 | Garoowe.
# Processing Record 467 ID:2065665 | Mount Barker.
# Processing Record 468 ID:3146487 | Raudeberg.
# Processing Record 469 ID:2445704 | Diffa.
# Processing Record 470 ID:2510485 | Tias.
# Processing Record 471 ID:3125287 | Cervo.
# Processing Record 472 ID:1265534 | Kurara.
# Processing Record 473 ID:145724 | Lucapa.
# Processing Record 474 ID:3176125 | Giffoni Valle Piana.
# Processing Record 475 ID:1337619 | Ugoofaaru.
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 476 ID:3385077 | Conde.
# Processing Record 477 ID:2090021 | Namatanai.
# Processing Record 478 ID:2077895 | Alice Springs.
# Processing Record 479 ID:113659 | Tabas.
# Processing Record 480 ID:380348 | Abu Zabad.
# City not found. Skipping...
# Processing Record 481 ID:4301317 | Morehead.
# Processing Record 482 ID:1803364 | Linqu.
# Processing Record 483 ID:3938415 | Ilo.
# Processing Record 484 ID:3492997 | Samana.
# Processing Record 485 ID:2109701 | Auki.
# Processing Record 486 ID:3347019 | Mossamedes.
# Processing Record 487 ID:4047434 | Russell.
# City not found. Skipping...
# Processing Record 488 ID:2112309 | Katsuura.
# Processing Record 489 ID:1797181 | Renqiu.
# Processing Record 490 ID:1795857 | Shaowu.
# Processing Record 491 ID:3693584 | Pimentel.
# Processing Record 492 ID:3671450 | Inirida.
# Processing Record 493 ID:3893629 | Coquimbo.
# Processing Record 494 ID:2068110 | Kununurra.
# Processing Record 495 ID:1525988 | Ayagoz.
# City not found. Skipping...
# Processing Record 496 ID:1785036 | Zhangye.
# Processing Record 497 ID:1337606 | Eydhafushi.
# Processing Record 498 ID:5563397 | Eureka.
# Processing Record 499 ID:5983720 | Iqaluit.
# Processing Record 500 ID:3832899 | Viedma.
# Processing Record 501 ID:1262403 | Murud.
# Processing Record 502 ID:105298 | Jizan.
# Processing Record 503 ID:893549 | Chipinge.
# Processing Record 504 ID:7071576 | Wuning.
# Processing Record 505 ID:4160789 | Key Biscayne.
# Processing Record 506 ID:2361082 | Dori.
# Processing Record 507 ID:2156643 | Mount Gambier.
# Processing Record 508 ID:3451234 | Rio Claro.
# Processing Record 509 ID:2246901 | Oussouye.
# City not found. Skipping...
# Processing Record 510 ID:1528796 | At-Bashi.
# Processing Record 511 ID:2449938 | Tenenkou.
# Processing Record 512 ID:2179825 | Waitati.
# Processing Record 513 ID:1524801 | Shieli.
# Processing Record 514 ID:342884 | Bahir Dar.
# Processing Record 515 ID:88834 | Tukrah.
# Processing Record 516 ID:533964 | Loukhi.
# Processing Record 517 ID:5583739 | Ada.
# Processing Record 518 ID:779622 | Avanuorri.
# City not found. Skipping...
# Processing Record 519 ID:2396853 | Omboue.
# Processing Record 520 ID:2610806 | Vagur.
# City not found. Skipping...
# Processing Record 521 ID:2125693 | Evensk.
# Processing Record 522 ID:1152633 | Krabi.
# Processing Record 523 ID:2269594 | Cascais.
# Processing Record 524 ID:3444199 | Puerto Suarez.
# Processing Record 525 ID:5855051 | 'Ewa Beach.
# Processing Record 526 ID:2450173 | Taoudenni.
# Processing Record 527 ID:1513087 | Nurota.
# Processing Record 528 ID:3356832 | Henties Bay.
# Processing Record 529 ID:477958 | Ust'-Shonosha.
# Processing Record 530 ID:922741 | Likasi.
# Processing Record 531 ID:1166073 | Sarai Alamgir.
# Processing Record 532 ID:4255151 | Bud.
# Processing Record 533 ID:1813828 | Danjiangkou.
# Processing Record 534 ID:5815135 | Washington.
# Processing Record 535 ID:1695546 | Pandan.
# Processing Record 536 ID:1591474 | Bac Lieu.
# Processing Record 537 ID:1705597 | Lookan.
# City not found. Skipping...
# Processing Record 538 ID:1056899 | Sambava.
# City not found. Skipping...
# Processing Record 539 ID:5895424 | Bay Roberts.
# Processing Record 540 ID:3457192 | Miguelopolis.
# Processing Record 541 ID:3374120 | Vila do Maio.
# Processing Record 542 ID:5563839 | Fortuna.
# Processing Record 543 ID:1626493 | Srandakan.
# Processing Record 544 ID:1278122 | Avanigadda.
# Processing Record 545 ID:3985168 | San Patricio.
# Processing Record 546 ID:2035707 | Mujiayingzi.
# Processing Record 547 ID:3035768 | Avallon.
# Processing Record 548 ID:1636308 | Manokwari.
# Processing Record 549 ID:5957776 | Fredericton.
# Processing Record 550 ID:1267390 | Kavaratti.
# Processing Record 551 ID:365763 | Tonj.
# Processing Record 552 ID:2690960 | Motala.
# City not found. Skipping...
# Processing Record 553 ID:1279290 | Agartala.
# Processing Record 554 ID:667303 | Sfantu Gheorghe.
# Processing Record 555 ID:1864009 | Fukuchiyama.
# Processing Record 556 ID:324172 | Alasehir.
# Processing Record 557 ID:964712 | Plettenberg Bay.
# Processing Record 558 ID:644509 | Nivala.
# Processing Record 559 ID:1283217 | Khanbari.
# Processing Record 560 ID:2270385 | Camacha.
# Processing Record 561 ID:2629833 | Husavik.
# Processing Record 562 ID:3897774 | Buin.
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#set up new df
zippedList =  list(zip(city_list, cloudiness, country, date, humidity, lat, lng, max_temp, wind_speed))

new_df = pd.DataFrame(zippedList,columns =['City', 'Cloudiness','Country','Date','Humidity','Lat',
                                          'Lng','Max Temp', 'Wind Speed'])
new_df.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   Punta Arenas          16      CL  1579489736        61 -53.15  -70.92
# 1        Talnakh          40      RU  1579489736        75  69.49   88.40
# 2  Sioux Lookout           5      CA  1579489736        84  50.10  -91.92
# 3          Bilma           0      NE  1579489736        27  18.69   12.92
# 4      Shaunavon          98      CA  1579489736        95  49.65 -108.42
#
#    Max Temp  Wind Speed
# 0     50.00       23.04
# 1    -20.20        6.71
# 2      1.40        4.70
# 3     55.13        9.80
# 4      5.25       11.05

# %%
# Specify the file to write to
new_df.to_csv(r"../output_data/new_list.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(new_df['Lat'],new_df['Max Temp'], marker="o", facecolors="lightblue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temp.")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(new_df['Lat'],new_df['Humidity'], marker="o", facecolors="lightblue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(new_df['Lat'],new_df['Cloudiness'], marker="o", facecolors="lightblue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.grid()
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(new_df['Lat'],new_df['Wind Speed'], marker="o", facecolors="lightblue", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid()
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#all cities in northern hemisphere
north_df = new_df[new_df['Lat']>=0]

x_values = north_df['Lat']
y_values = north_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(.01,-20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.8425433899333589

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
#all cities in northern hemisphere
south_df = new_df[new_df['Lat']<=0]
south_df

x_values = south_df['Lat']
y_values = south_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,95),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.48373611119748294

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.3454332571477064

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.12670922103707133

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.25728510356471274

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,5),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.22760731474689772

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = north_df['Lat']
y_values = north_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.13708877838726594

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = south_df['Lat']
y_values = south_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values, facecolors="lightblue", edgecolors="black")
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,30),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.savefig(f'{states}_data/{states}_bar_confirmed.png',dpi=200)
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.29170913306434754
